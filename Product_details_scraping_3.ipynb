# %%
import requests
from bs4 import BeautifulSoup
import random
import time
import pandas as pd

# List of user agents to rotate
USER_AGENTS = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.104 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36',
]

# Function to get the HTML content of a product page
def get_product_page(asin):
    url = f"https://www.amazon.com/dp/{asin}"
    headers = {
        'User-Agent': random.choice(USER_AGENTS),
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'DNT': '1',  # Do Not Track Request Header
        'Connection': 'keep-alive',
    }

    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.text
        else:
            print(f"Failed to retrieve page for ASIN {asin}, Status code: {response.status_code}")
            return None
    except Exception as e:
        print(f"Error fetching page for ASIN {asin}: {e}")
        return None

# Function to parse product details from the HTML content
def parse_product_details(asin, html_content):
    soup = BeautifulSoup(html_content, 'html.parser')

    product_details = {
        "ASIN": asin,
        "Product Name": None,
        "Price": None,
        "Brand": None,
        "Rating": None,
        "Product Description": None,
        "Dimensions": None,
        "Weight": None
    }

    # Parse product name
    product_name_tag = soup.find(id='productTitle')
    if product_name_tag:
        product_details['Product Name'] = product_name_tag.get_text(strip=True)

    # Parse price
    price_tag = soup.find('span', {'id': 'priceblock_ourprice'}) or soup.find('span', {'id': 'priceblock_dealprice'})
    if price_tag:
        product_details['Price'] = price_tag.get_text(strip=True)

    # Parse brand
    brand_tag = soup.find('a', {'id': 'bylineInfo'})
    if brand_tag:
        product_details['Brand'] = brand_tag.get_text(strip=True)

    # Parse rating
    rating_tag = soup.find('span', {'class': 'a-icon-alt'})
    if rating_tag:
        product_details['Rating'] = rating_tag.get_text(strip=True)

    # Parse product description
    description_tag = soup.find('div', {'id': 'feature-bullets'})
    if description_tag:
        product_details['Product Description'] = description_tag.get_text(strip=True)

    # Parse dimensions and weight
    technical_details = soup.find('table', {'id': 'productDetails_techSpec_section_1'})
    if technical_details:
        for row in technical_details.find_all('tr'):
            th = row.find('th').get_text(strip=True)
            td = row.find('td').get_text(strip=True)
            if 'Dimensions' in th:
                product_details['Dimensions'] = td
            if 'Weight' in th:
                product_details['Weight'] = td

    return product_details

# Function to scrape product details using ASIN
def scrape_product_details(asin):
    print(f"Scraping ASIN: {asin}")
    html_content = get_product_page(asin)
    if html_content:
        product_details = parse_product_details(asin, html_content)
        return product_details
    else:
        return None

# Read the ASINs from the laptop_reviews.csv file
df_reviews = pd.read_csv("amazon_tv_reviews.csv")

# List of ASINs from the csv file
asins = df_reviews['ASIN'].unique()  # Ensure only unique ASINs are used

# Scrape product details for each ASIN and store in a list
product_data = []
for asin in asins:
    details = scrape_product_details(asin)
    if details:
        product_data.append(details)
    # Sleep to avoid being blocked
    time.sleep(random.uniform(1, 3))

# Convert the list of product details into a DataFrame
df_products = pd.DataFrame(product_data)

# Merge product details with the existing reviews
df_combined = pd.merge(df_reviews, df_products, on='ASIN', how='left')

# Save the combined data to a new CSV file
df_combined.to_csv("combined_TV_reviews_details.csv", index=False)

# Print the combined DataFrame
print(df_combined)
# Out:
# Scraping ASIN: B0BTTVRWPR
# Scraping ASIN: B0BCMRRKRX
# Scraping ASIN: B09ZLTMWWH
# Scraping ASIN: B0CJDSNN4T
# Scraping ASIN: B0D2WGBQ5Y
# Scraping ASIN: B0B3GTSQ9Q
# Scraping ASIN: B0BMGVZC5M
# Scraping ASIN: B09RMR23XL
# Scraping ASIN: B00DFVXBRU
# Scraping ASIN: nan
# Failed to retrieve page for ASIN nan, Status code: 404
#              ASIN  Product_Name  \
# 0      B0BTTVRWPR           NaN
# 1      B0BTTVRWPR           NaN
# 2      B0BTTVRWPR           NaN
# 3      B0BTTVRWPR           NaN
# 4      B0BTTVRWPR           NaN
# ...           ...           ...
# 19525         NaN           NaN
# 19526         NaN           NaN
# 19527         NaN           NaN
# 19528         NaN           NaN
# 19529         NaN           NaN
#
#                                            Review_Title  \
# 0                            A Smart TV running Fire TV
# 1                            Great price to performance
# 2                        Nice picture and value priced!
# 3      Great TV for the price! eARC issues were my own!
# 4                                       Picture Perfect
# ...                                                 ...
# 19525                                               NaN
# 19526                                               NaN
# 19527                                               NaN
# 19528                                               NaN
# 19529                                               NaN
#
#                                           Review_Content  Review_Stars  \
# 0      I have a TV with Fire Stick. I have a TV with ...           5.0
# 1      I recently bought an INSIGNIA 50-inch Class F3...           5.0
# 2      Purchased this 65" TV on Amazon for 299.00 and...           5.0
# 3      I ordered this TV and picked it up during the ...           5.0
# 4      I specifically searched for Insignia brand TV ...           5.0
# ...                                                  ...           ...
# 19525                                                NaN           NaN
# 19526                                                NaN           NaN
# 19527                                                NaN           NaN
# 19528                                                NaN           NaN
# 19529                                                NaN           NaN
#
#                                              Review_Date       Reviewer_Name  \
# 0      Reviewed in the United States on November 9, 2020      George Moncure
# 1      Reviewed in the United States on September 14,...        Brook Jolley
# 2         Reviewed in the United States on July 24, 2024       Geoffrey Owen
# 3        Reviewed in the United States on August 9, 2022                 NaN
# 4      Reviewed in the United States on September 19,...      George Moncure
# ...                                                  ...                 ...
# 19525                                                NaN   Andrew John Lewis
# 19526                                                NaN              BlairG
# 19527                                                NaN  leroy d gilliam jr
# 19528                                                NaN           imawareru
# 19529                                                NaN         Ben Vickers
#
#        Verified_Purchase                  Helpful_Votes  \
# 0      Verified Purchase  663 people found this helpful
# 1      Verified Purchase   10 people found this helpful
# 2      Verified Purchase   46 people found this helpful
# 3      Verified Purchase  296 people found this helpful
# 4      Verified Purchase    4 people found this helpful
# ...                  ...                            ...
# 19525                NaN                            NaN
# 19526                NaN                            NaN
# 19527                NaN                            NaN
# 19528                NaN                            NaN
# 19529                NaN                            NaN
#
#                                               Review_URL  \
# 0      https://www.amazon.com/product-reviews/B0BTTVR...
# 1      https://www.amazon.com/product-reviews/B0BTTVR...
# 2      https://www.amazon.com/product-reviews/B0BTTVR...
# 3      https://www.amazon.com/product-reviews/B0BTTVR...
# 4      https://www.amazon.com/product-reviews/B0BTTVR...
# ...                                                  ...
# 19525                                                NaN
# 19526                                                NaN
# 19527                                                NaN
# 19528                                                NaN
# 19529                                                NaN
#
#                                             Product Name Price  \
# 0      INSIGNIA 50-inch Class F30 Series LED 4K UHD S...  None
# 1      INSIGNIA 50-inch Class F30 Series LED 4K UHD S...  None
# 2      INSIGNIA 50-inch Class F30 Series LED 4K UHD S...  None
# 3      INSIGNIA 50-inch Class F30 Series LED 4K UHD S...  None
# 4      INSIGNIA 50-inch Class F30 Series LED 4K UHD S...  None
# ...                                                  ...   ...
# 19525                                                NaN   NaN
# 19526                                                NaN   NaN
# 19527                                                NaN   NaN
# 19528                                                NaN   NaN
# 19529                                                NaN   NaN
#
#                           Brand              Rating  \
# 0      Visit the INSIGNIA Store  4.4 out of 5 stars
# 1      Visit the INSIGNIA Store  4.4 out of 5 stars
# 2      Visit the INSIGNIA Store  4.4 out of 5 stars
# 3      Visit the INSIGNIA Store  4.4 out of 5 stars
# 4      Visit the INSIGNIA Store  4.4 out of 5 stars
# ...                         ...                 ...
# 19525                       NaN                 NaN
# 19526                       NaN                 NaN
# 19527                       NaN                 NaN
# 19528                       NaN                 NaN
# 19529                       NaN                 NaN
#
#                                      Product Description Dimensions Weight
# 0      About this item4K Ultra HD (2160p resolution) ...       None   None
# 1      About this item4K Ultra HD (2160p resolution) ...       None   None
# 2      About this item4K Ultra HD (2160p resolution) ...       None   None
# 3      About this item4K Ultra HD (2160p resolution) ...       None   None
# 4      About this item4K Ultra HD (2160p resolution) ...       None   None
# ...                                                  ...        ...    ...
# 19525                                                NaN        NaN    NaN
# 19526                                                NaN        NaN    NaN
# 19527                                                NaN        NaN    NaN
# 19528                                                NaN        NaN    NaN
# 19529                                                NaN        NaN    NaN
#
# [19530 rows x 17 columns]

# %%
import requests
from bs4 import BeautifulSoup
import random
import time
import pandas as pd

# List of user agents to rotate
USER_AGENTS = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.104 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36',
]

# Function to get the HTML content of a product page
def get_product_page(asin):
    url = f"https://www.amazon.com/dp/{asin}"
    headers = {
        'User-Agent': random.choice(USER_AGENTS),
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'DNT': '1',  # Do Not Track Request Header
        'Connection': 'keep-alive',
    }

    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.text
        else:
            print(f"Failed to retrieve page for ASIN {asin}, Status code: {response.status_code}")
            return None
    except Exception as e:
        print(f"Error fetching page for ASIN {asin}: {e}")
        return None

# Function to parse product details from the HTML content
def parse_product_details(asin, html_content):
    soup = BeautifulSoup(html_content, 'html.parser')

    product_details = {
        "ASIN": asin,
        "Product Name": None,
        "Price": None,
        "Brand": None,
        "Rating": None,
        "Product Description": None,
        "Dimensions": None,
        "Weight": None
    }

    # Parse product name
    product_name_tag = soup.find(id='productTitle')
    if product_name_tag:
        product_details['Product Name'] = product_name_tag.get_text(strip=True)

    # Parse price
    price_tag = soup.find('span', {'id': 'priceblock_ourprice'}) or soup.find('span', {'id': 'priceblock_dealprice'})
    if price_tag:
        product_details['Price'] = price_tag.get_text(strip=True)

    # Parse brand
    brand_tag = soup.find('a', {'id': 'bylineInfo'})
    if brand_tag:
        product_details['Brand'] = brand_tag.get_text(strip=True)

    # Parse rating
    rating_tag = soup.find('span', {'class': 'a-icon-alt'})
    if rating_tag:
        product_details['Rating'] = rating_tag.get_text(strip=True)

    # Parse product description
    description_tag = soup.find('div', {'id': 'feature-bullets'})
    if description_tag:
        product_details['Product Description'] = description_tag.get_text(strip=True)

    # Parse dimensions and weight
    technical_details = soup.find('table', {'id': 'productDetails_techSpec_section_1'})
    if technical_details:
        for row in technical_details.find_all('tr'):
            th = row.find('th').get_text(strip=True)
            td = row.find('td').get_text(strip=True)
            if 'Dimensions' in th:
                product_details['Dimensions'] = td
            if 'Weight' in th:
                product_details['Weight'] = td

    return product_details

# Function to scrape product details using ASIN
def scrape_product_details(asin):
    print(f"Scraping ASIN: {asin}")
    html_content = get_product_page(asin)
    if html_content:
        product_details = parse_product_details(asin, html_content)
        return product_details
    else:
        return None

# Read the ASINs from the earphones_reviews.csv file
df_reviews = pd.read_csv("earphones_reviews.csv")

# List of ASINs from the csv file
asins = df_reviews['ASIN'].unique()  # Ensure only unique ASINs are used

# Scrape product details for each ASIN and store in a list
product_data = []
for asin in asins:
    details = scrape_product_details(asin)
    if details:
        product_data.append(details)
    # Sleep to avoid being blocked
    time.sleep(random.uniform(1, 3))

# Convert the list of product details into a DataFrame
df_products = pd.DataFrame(product_data)

# Merge product details with the existing reviews
df_combined = pd.merge(df_reviews, df_products, on='ASIN', how='left')

# Save the combined data to a new CSV file
df_combined.to_csv("combined_earphones_reviews_details.csv", index=False)

# Print the combined DataFrame
print(df_combined)
# Out:
# Scraping ASIN: B07PXGQC1Q
# Scraping ASIN: B0BQPNMXQV
# Scraping ASIN: B0D635YLCT
# Scraping ASIN: B0BTYCRJSS
# Scraping ASIN: B0C1QNRGHC
# Scraping ASIN: B09FT58QQP
# Scraping ASIN: B0C3W4MNN1
# Scraping ASIN: B096SV8SJG
# Scraping ASIN: B0C1QWWZR4
# Scraping ASIN: B0CZNFV5W2
# Scraping ASIN: B07HH1QSLB
# Scraping ASIN: B09FLNSYDZ
# Scraping ASIN: B09DT48V16
# Scraping ASIN: B0CX1SZPH3
# Scraping ASIN: B0CH9LSX5M
# Scraping ASIN: B0D9K5K5M3
# Scraping ASIN: B0BM4HGSFJ
# Scraping ASIN: B0B1LVC5VZ
# Scraping ASIN: B0D5HG7TC3
# Scraping ASIN: B09KGLRF8J
# Scraping ASIN: B07R5QD598
# Scraping ASIN: B09TN4MP6V
# Scraping ASIN: B0CRT6HQ82
# Scraping ASIN: B0DB2DSVWF
# Scraping ASIN: B01M0GB8CC
# Scraping ASIN: B0D17TFVTF
# Scraping ASIN: B09BFFGQ5N
# Scraping ASIN: B07J2Z5DBM
# Scraping ASIN: B0CTD56NJ2
# Scraping ASIN: B0DDKSSWTC
# Scraping ASIN: B09JL41N9C
# Scraping ASIN: B0CPJG173J
# Scraping ASIN: B0CP8PFX7Y
# Scraping ASIN: B0D28SBFK9
# Scraping ASIN: B09HN594TL
# Scraping ASIN: B0CF7GYNW2
# Scraping ASIN: B08L6ZYW21
# Scraping ASIN: B0CSXV3GK4
# Scraping ASIN: B0B4VZYGBR
# Scraping ASIN: B003EM8008
# Scraping ASIN: B0CX1TJ228
# Scraping ASIN: B0CT8K8LB7
# Scraping ASIN: B0CRTYZG5C
# Scraping ASIN: B0DFPK14GH
# Scraping ASIN: B0CPM8TPR6
# Scraping ASIN: B0D4ZFSDV4
# Scraping ASIN: B0170RBJ9Q
# 2      B07PXGQC1Q           NaN
# 3      B07PXGQC1Q           NaN
# 4      B07PXGQC1Q           NaN
# ...           ...           ...
# 19206         NaN           NaN
# 19207         NaN           NaN
# 19208         NaN           NaN
# 19209         NaN           NaN
# 19210         NaN           NaN
#
#                                             Review_Title  \
# 0                                      worked perfectly!
# 1                               Phenomenal Apple product
# 2      **⭐️⭐️⭐️⭐️⭐️ Best Wireless Earbuds I've Ever O...
# 3                                     Quality product 👏🏾
# 4                      Seamless and High-Quality AirPods
# ...                                                  ...
# 19206                                                NaN
# 19207                                                NaN
# 19208                                                NaN
# 19209                                                NaN
# 19210                                                NaN
#
#                                           Review_Content  Review_Stars  \
# 0      I recently got the Apple AirPods (2nd Generati...           5.0
# 1      Everything Apple makes is of the highest quali...           5.0
# 2      I recently purchased the Apple AirPods (2nd Ge...           5.0
# 3      What I like about this it connects pretty fast...           5.0
# 4      AirPods are fantastic! They offer a seamless c...           5.0
# ...                                                  ...           ...
# 19206                                                NaN           NaN
# 19207                                                NaN           NaN
# 19208                                                NaN           NaN
# 19209                                                NaN           NaN
# 19210                                                NaN           NaN
#
#                                              Review_Date  \
# 0       Reviewed in the United States on August 30, 2024
# 1      Reviewed in the United States on September 11,...
# 2         Reviewed in the United States on July 24, 2024
# 3      Reviewed in the United States on September 12,...
# 4       Reviewed in the United States on August 30, 2024
# ...                                                  ...
# 19206                                                NaN
# 19207                                                NaN
# 19208                                                NaN
# 19209                                                NaN
# 19210                                                NaN
#
#               Reviewer_Name  Verified_Purchase                  Helpful_Votes  \
# 0                   Chandan  Verified Purchase   23 people found this helpful
# 1                    Jeremy  Verified Purchase  One person found this helpful
# 2                   Chandan  Verified Purchase   57 people found this helpful
# 3                Melanie M.  Verified Purchase  One person found this helpful
# 4      Christopher Domenici  Verified Purchase    4 people found this helpful
# ...                     ...                ...                            ...
# 19206                kapm77                NaN                            NaN
# 19207              Khalysee                NaN                            NaN
# 19208       Justine Johnson                NaN                            NaN
# 19209             Old crank                NaN                            NaN
# 19210          I_am_ble55ed                NaN                            NaN
#
#                                               Review_URL  \
# 0      https://www.amazon.com/product-reviews/B07PXGQ...
# 1      https://www.amazon.com/product-reviews/B07PXGQ...
# 2      https://www.amazon.com/product-reviews/B07PXGQ...
# 3      https://www.amazon.com/product-reviews/B07PXGQ...
# 4      https://www.amazon.com/product-reviews/B07PXGQ...
# ...                                                  ...
# 19206                                                NaN
# 19207                                                NaN
# 19208                                                NaN
# 19209                                                NaN
# 19210                                                NaN
#
#                                             Product Name Price  \
# 0      Apple AirPods (2nd Generation) Wireless Ear Bu...  None
# 1      Apple AirPods (2nd Generation) Wireless Ear Bu...  None
# 2      Apple AirPods (2nd Generation) Wireless Ear Bu...  None
# 3      Apple AirPods (2nd Generation) Wireless Ear Bu...  None
# 4      Apple AirPods (2nd Generation) Wireless Ear Bu...  None
# ...                                                  ...   ...
# 19206                                                NaN   NaN
# 19207                                                NaN   NaN
# 19208                                                NaN   NaN
# 19209                                                NaN   NaN
# 19210                                                NaN   NaN
#
#                        Brand              Rating  \
# 0      Visit the Apple Store  3.4 out of 5 stars
# 1      Visit the Apple Store  3.4 out of 5 stars
# 2      Visit the Apple Store  3.4 out of 5 stars
# 3      Visit the Apple Store  3.4 out of 5 stars
# 4      Visit the Apple Store  3.4 out of 5 stars
# ...                      ...                 ...
# 19206                    NaN                 NaN
# 19207                    NaN                 NaN
# 19208                    NaN                 NaN
# 19209                    NaN                 NaN
# 19210                    NaN                 NaN
#
#                                      Product Description Dimensions Weight
# 0      About this itemHIGH-QUALITY SOUND — Powered by...       None   None
# 1      About this itemHIGH-QUALITY SOUND — Powered by...       None   None
# 2      About this itemHIGH-QUALITY SOUND — Powered by...       None   None
# 3      About this itemHIGH-QUALITY SOUND — Powered by...       None   None
# 4      About this itemHIGH-QUALITY SOUND — Powered by...       None   None
# ...                                                  ...        ...    ...
# 19206                                                NaN        NaN    NaN
# 19207                                                NaN        NaN    NaN
# 19208                                                NaN        NaN    NaN
# 19209                                                NaN        NaN    NaN
# 19210                                                NaN        NaN    NaN
#
# [19211 rows x 17 columns]

# %%
import requests
from bs4 import BeautifulSoup
import random
import time
import pandas as pd

# List of user agents to rotate
USER_AGENTS = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.104 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36',
]

# Function to get the HTML content of a product page
def get_product_page(asin):
    url = f"https://www.amazon.com/dp/{asin}"
    headers = {
        'User-Agent': random.choice(USER_AGENTS),
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'DNT': '1',  # Do Not Track Request Header
        'Connection': 'keep-alive',
    }

    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.text
        else:
            print(f"Failed to retrieve page for ASIN {asin}, Status code: {response.status_code}")
            return None
    except Exception as e:
        print(f"Error fetching page for ASIN {asin}: {e}")
        return None

# Function to parse product details from the HTML content
def parse_product_details(asin, html_content):
    soup = BeautifulSoup(html_content, 'html.parser')

    product_details = {
        "ASIN": asin,
        "Product Name": None,
        "Price": None,
        "Brand": None,
        "Rating": None,
        "Product Description": None,
        "Dimensions": None,
        "Weight": None
    }

    # Parse product name
    product_name_tag = soup.find(id='productTitle')
    if product_name_tag:
        product_details['Product Name'] = product_name_tag.get_text(strip=True)

    # Parse price
    price_tag = soup.find('span', {'id': 'priceblock_ourprice'}) or soup.find('span', {'id': 'priceblock_dealprice'})
    if price_tag:
        product_details['Price'] = price_tag.get_text(strip=True)

    # Parse brand
    brand_tag = soup.find('a', {'id': 'bylineInfo'})
    if brand_tag:
        product_details['Brand'] = brand_tag.get_text(strip=True)

    # Parse rating
    rating_tag = soup.find('span', {'class': 'a-icon-alt'})
    if rating_tag:
        product_details['Rating'] = rating_tag.get_text(strip=True)

    # Parse product description
    description_tag = soup.find('div', {'id': 'feature-bullets'})
    if description_tag:
        product_details['Product Description'] = description_tag.get_text(strip=True)

    # Parse dimensions and weight
    technical_details = soup.find('table', {'id': 'productDetails_techSpec_section_1'})
    if technical_details:
        for row in technical_details.find_all('tr'):
            th = row.find('th').get_text(strip=True)
            td = row.find('td').get_text(strip=True)
            if 'Dimensions' in th:
                product_details['Dimensions'] = td
            if 'Weight' in th:
                product_details['Weight'] = td

    return product_details

# Function to scrape product details using ASIN
def scrape_product_details(asin):
    print(f"Scraping ASIN: {asin}")
    html_content = get_product_page(asin)
    if html_content:
        product_details = parse_product_details(asin, html_content)
        return product_details
    else:
        return None

# Read the ASINs from the laptop_reviews.csv file
df_reviews = pd.read_csv("amazon_mobile_reviews.csv")

# List of ASINs from the csv file
asins = df_reviews['ASIN'].unique()  # Ensure only unique ASINs are used

# Scrape product details for each ASIN and store in a list
product_data = []
for asin in asins:
    details = scrape_product_details(asin)
    if details:
        product_data.append(details)
    # Sleep to avoid being blocked
    time.sleep(random.uniform(1, 3))

# Convert the list of product details into a DataFrame
df_products = pd.DataFrame(product_data)

# Merge product details with the existing reviews
df_combined = pd.merge(df_reviews, df_products, on='ASIN', how='left')

# Save the combined data to a new CSV file
df_combined.to_csv("combined_mobile_reviews_details.csv", index=False)

# Print the combined DataFrame
print(df_combined)
# Out:
# /var/folders/5m/0m830m411nq16g1t6g6w6fym0000gn/T/ipykernel_35613/37864419.py:101: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_reviews = pd.read_csv("amazon_mobile_reviews.csv")
# Scraping ASIN: B0CMDJ844V
# Scraping ASIN: B0CMZ8ZBVN
# Scraping ASIN: B0CF2PV74C
# Scraping ASIN: B0C544TBQM
# Scraping ASIN: B08PNB9B5Z
# Scraping ASIN: B07Z3XZDT5
# Scraping ASIN: B077RM9WJB
# Scraping ASIN: B0C2W7YYHM
# Scraping ASIN: B0BV5SV5HL
# Scraping ASIN: B08G5B4PV5
# Scraping ASIN: B08CFSZLQ4
# Scraping ASIN: B08KRKFHGV
# Scraping ASIN: B09G2BN89Q
# Scraping ASIN: B0BYHC3ZMS
# Scraping ASIN: B08HVXC89J
# Scraping ASIN: B083B8HH98
# Scraping ASIN: B0BLW47H3M
# Scraping ASIN: B00R2K4LCY
# Scraping ASIN: B08NWBY8YJ
# Scraping ASIN: B0BYLRBG4M
# Scraping ASIN: B089HNHZ17
# Scraping ASIN: B0845ZVJW3
# Scraping ASIN: B0BYHB4DF5
# Scraping ASIN: B09FRBJZSY
# Scraping ASIN: B08126B44P
# Scraping ASIN: B0BYLM8RRW
# Scraping ASIN: B0BVL4VRXN
# Scraping ASIN: B0C5443MCX
# Scraping ASIN: B07Z43ZPTT
# Scraping ASIN: B08HC5GMK2
# Scraping ASIN: B08Z63QRD2
# Scraping ASIN: B07H8PXT7K
# Scraping ASIN: B093CB2R6L
# Scraping ASIN: B07FNZ85WF
# Scraping ASIN: B08M5RFKWK
# Scraping ASIN: B093ZCPS14
# Scraping ASIN: B07X4B9G32
# Scraping ASIN: B07KFN43WC
# Scraping ASIN: B076XLLCQC
# Scraping ASIN: B07R5CJDD7
# Scraping ASIN: B079Z792J7
# Scraping ASIN: B083JN4KJX
# Scraping ASIN: B0BSLR2L5R
# Scraping ASIN: B07RL93F7T
# Scraping ASIN: B07KNB1TN8
# Scraping ASIN: B08HJZDW6M
# Scraping ASIN: B082YF9MMW
# Scraping ASIN: B0CLHJTQ3X
# Scraping ASIN: B0B9QF9DFQ
# Scraping ASIN: B0CHNSDSG6
# Scraping ASIN: B0D9325QGG
# Scraping ASIN: B0D91GMFGN
# Scraping ASIN: B0CSSTZSFX
# Scraping ASIN: B0CMZFH1Z6
# Scraping ASIN: B0CCT1S3Z2
# Scraping ASIN: B0BZYZ61X3
# Scraping ASIN: B0CQ1YSGN4
# Scraping ASIN: B09XC6H47J
# Scraping ASIN: B0BD1Z7CQQ
# Scraping ASIN: B0CDLV84HT
# Scraping ASIN: B09Y24RQXZ
# Scraping ASIN: B0CJ36DGGT
# Scraping ASIN: B0BW69LVCF
# Scraping ASIN: B09KV9FWPT
# Scraping ASIN: B0CBSDMT8D
# Scraping ASIN: B09LN7D1TR
# Scraping ASIN: B0CZVP6BVK
# Scraping ASIN: B0CVKJ9Z5M
# Scraping ASIN: B0CCGTDSH3
# Scraping ASIN: B0CGJYNB72
# Scraping ASIN: B0C8GPFSNR
# Scraping ASIN: B09R9CVK7B
# Scraping ASIN: B0BPDS5MM9
# Scraping ASIN: B09Q8JVC68
# Scraping ASIN: B0CK193XBM
# Scraping ASIN: B097TGQ5M2
# Scraping ASIN: B07VTN5R6W
# Scraping ASIN: B0BLXMXZYH
# Scraping ASIN: B09TSGXHF4
# Scraping ASIN: B0D47SMKQL
# Scraping ASIN: B0C9TYC866
# Scraping ASIN: B0BYH5JBK7
# Scraping ASIN: B09NRV6WZD
# Scraping ASIN: B0B315V86X
# Scraping ASIN: B09V349ZM7
# Scraping ASIN: B08MVD5DM3
# Scraping ASIN: B0CQLSMRJ1
# Scraping ASIN: B0BJDWKJ2F
# Scraping ASIN: nan
#               ASIN  Product_Name                                Review_Title  \
# 0       B0CMDJ844V           NaN     Super Fast Cell Phone with Great Camera
# 1       B0CMDJ844V           NaN  SAMSUNG Galaxy S24 Ultra Cell Phone, 512GB
# 2       B0CMDJ844V           NaN   The perfect phone that doesn't come cheap
# 3       B0CMDJ844V           NaN       Great phone and much improved battery
# 4       B0CMDJ844V           NaN                           Big and beautiful
# ...            ...           ...                                         ...
# 127166         NaN           NaN                                         NaN
# 127167         NaN           NaN                                         NaN
# 127168         NaN           NaN                                         NaN
# 127169         NaN           NaN                                         NaN
# 127170         NaN           NaN                                         NaN
#
#                                            Review_Content  Review_Stars  \
# 0       ⭐️⭐️⭐️⭐️⭐️\n\nThe SAMSUNG Galaxy S24 Ultra is ...           5.0
# 1       The Samsung Galaxy S24 Ultra, with its impress...           5.0
# 2       PLEEEEEASE people, stop complaining about the ...           5.0
# 3       I opted for the S24 Ultra after much deliberat...           5.0
# 4       Phone is big and beautiful. OS is super quick....           5.0
# ...                                                   ...           ...
# 127166                                                NaN           NaN
# 127167                                                NaN           NaN
# 127168                                                NaN           NaN
# 127169                                                NaN           NaN
# 127170                                                NaN           NaN
#
#                                               Review_Date  \
# 0        Reviewed in the United States on August 15, 2024
# 1          Reviewed in the United States on July 24, 2024
# 2       Reviewed in the United States on February 15, ...
# 3       Reviewed in the United States on September 17,...
# 4        Reviewed in the United States on August 30, 2024
# ...                                                   ...
# 127166                                                NaN
# 127167                                                NaN
# 127168                                                NaN
# 127169                                                NaN
# 127170                                                NaN
#
#                       Reviewer_Name  Verified_Purchase  \
# 0                                MZ  Verified Purchase
# 1                       ideal deals  Verified Purchase
# 2                                MZ  Verified Purchase
# 3                          Benjamin  Verified Purchase
# 4                            Adrian  Verified Purchase
# ...                             ...                ...
# 127166  Sergio Gustavo Garcia Rojas                NaN
# 127167          Jorge Luis Dionisio                NaN
# 127168                          NaN                NaN
# 127169                    Ariana pf                NaN
# 127170                        Reyna                NaN
#
#                         Helpful_Votes  \
# 0        36 people found this helpful
# 1        24 people found this helpful
# 2       533 people found this helpful
# 3       One person found this helpful
# 4         8 people found this helpful
# ...                               ...
# 127166                            NaN
# 127167                            NaN
# 127168                            NaN
# 127169                            NaN
# 127170                            NaN
#
#                                                Review_URL  \
# 0       https://www.amazon.com/product-reviews/B0CMDJ8...
# 1       https://www.amazon.com/product-reviews/B0CMDJ8...
# 2       https://www.amazon.com/product-reviews/B0CMDJ8...
# 3       https://www.amazon.com/product-reviews/B0CMDJ8...
# 4       https://www.amazon.com/product-reviews/B0CMDJ8...
# ...                                                   ...
# 127166                                                NaN
# 127167                                                NaN
# 127168                                                NaN
# 127169                                                NaN
# 127170                                                NaN
#
#                                              Product Name Price  \
# 0       SAMSUNG Galaxy S24 Ultra Cell Phone, 256GB AI ...  None
# 1       SAMSUNG Galaxy S24 Ultra Cell Phone, 256GB AI ...  None
# 2       SAMSUNG Galaxy S24 Ultra Cell Phone, 256GB AI ...  None
# 3       SAMSUNG Galaxy S24 Ultra Cell Phone, 256GB AI ...  None
# 4       SAMSUNG Galaxy S24 Ultra Cell Phone, 256GB AI ...  None
# ...                                                   ...   ...
# 127166                                               None  None
# 127167                                               None  None
# 127168                                               None  None
# 127169                                               None  None
# 127170                                               None  None
#
#                           Brand              Rating  \
# 0       Visit the SAMSUNG Store  4.5 out of 5 stars
# 1       Visit the SAMSUNG Store  4.5 out of 5 stars
# 2       Visit the SAMSUNG Store  4.5 out of 5 stars
# 3       Visit the SAMSUNG Store  4.5 out of 5 stars
# 4       Visit the SAMSUNG Store  4.5 out of 5 stars
# ...                         ...                 ...
# 127166                     None                None
# 127167                     None                None
# 127168                     None                None
# 127169                     None                None
# 127170                     None                None
#
#                                       Product Description Dimensions Weight
# 0       About this itemCIRCLE & SEARCH¹ IN A SNAP: Wha...       None   None
# 1       About this itemCIRCLE & SEARCH¹ IN A SNAP: Wha...       None   None
# 2       About this itemCIRCLE & SEARCH¹ IN A SNAP: Wha...       None   None
# 3       About this itemCIRCLE & SEARCH¹ IN A SNAP: Wha...       None   None
# 4       About this itemCIRCLE & SEARCH¹ IN A SNAP: Wha...       None   None
# ...                                                   ...        ...    ...
# 127166                                               None       None   None
# 127167                                               None       None   None
# 127168                                               None       None   None
# 127169                                               None       None   None
# 127170                                               None       None   None
#
# [127171 rows x 17 columns]
